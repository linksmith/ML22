# %% [markdown]
# # Timeseries with recurrent neural networks

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('dark_background')

# %% [markdown]
# # 1.0 Sunspots
# ## 1.1 Loading data

# %%
import sys
sys.path.insert(0, "../..")
from src.data import make_dataset
from pathlib import Path
import gin

datadir = Path("../../data/raw")
data = make_dataset.get_sunspots(datadir=datadir)
data.head()
# Out:
# 2023-05-18 19:58:17.101007: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-18 19:58:17.235322: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-18 19:58:17.236174: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-18 19:58:18.622858: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-18 19:58:21.919 | INFO     | src.data.make_dataset:get_sunspots:86 - ../../data/raw/sunspots.csv does not exist, retrieving
#        year  MonthlyMean
# 0  1749.042         96.7
# 1  1749.123        104.3
# 2  1749.204        116.7
# 3  1749.288         92.8
# 4  1749.371        141.7

# %% [markdown]
# This is data on sunspots, since 1749, in a pandas dataframe. Let us cast this to a `float32` Torch Tensor.
#
# We first need to get the numpy data out of the pandas, and the cast that to a float32 Tensor.

# %%
import torch
series = data['MonthlyMean']
tensordata = torch.from_numpy(series.to_numpy()).type(torch.float32)
tensordata
# Out:
# tensor([ 96.7000, 104.3000, 116.7000,  ..., 110.9000, 122.6000,  96.4000])

# %%
plt.plot(tensordata);

# %% [markdown]
# ## 1.2 Train-test split
# There seems to be some pattern. But also a lot of noise. We need to take this into account for our final model: it might be hard to get very high accuracy, because we dont have any additional features (could you think of possible relevant features?).
#
# So let's make a train-test split, and normalize on the trainset. Note that we split on past-future! (Why is this important?)

# %%
# Train test split
split = 2500
train = tensordata[:split]

norm = max(train)
test = tensordata[split:]

train = train / norm
test = test/ norm

# %% [markdown]
# What would go wrong if you normalize on the max of the testset?

# %%
# reduce steps back to months, starting in 1749
idx0 = torch.arange(0, len(train)) / 12 + 1749
idx1 = torch.arange(0, len(test)) / 12 + idx0.max()
fig, axs = plt.subplots(2, sharex=True)
axs[0].plot(idx0, train)
axs[1].plot(idx1,test)

# %% [markdown]
# ## 1.3 Windowing
#
# Now, let's use our windowed datagenerator.
#
# Regarding the windowsize, we will have to ask ourselves: what is a reasonable time, we will need to look into the past to be able to predict the future? If we make it too long, we will get irrelevant data (eg, does the amount of sunspots a hundred years still impact significantly the sunspots in 2020? If you think so, you should increase your window by a lot!)

# %%
from src.data import data_tools

window_size = 26 # this is just a wild guess. A bit over 2 years.
idx = data_tools.window(train, window_size)
trainset = train[idx]
idx = data_tools.window(test, window_size)
testset = test[idx]
trainset.shape, testset.shape
# Out:
# (torch.Size([2475, 26]), torch.Size([767, 26]))

# %% [markdown]
# Ok, that is looking good. We squeezed out 2475 training examples out of this long, single timeseries.
#
# ## 1.4 A custom dataset
#
# Let's make the data 3D, just as our timeseries model will need to have it. We just have one feature, so that is just a dimension of 1.

# %%
from torch.utils.data import DataLoader
trainset = trainset[...,None]
testset = testset[..., None]

# %% [markdown]
# We can implement a Dataset in PyTorch.
# According to the [documentation](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#creating-a-custom-dataset-for-your-files)
# > A custom Dataset class must implement three functions: `__init__`, ` __len__`, and `__getitem__`
#
#
# The functions with the double underscores are called "dunder" function.
# The `__len__` function is the function that is called when you do `len(object)`, the `__getitem__` function is called when you do `object[idx]` and `idx` is passed as an argument.
#
# We can inherit the `Dataset` class, and if we implement a `__len__` and `__getitem__` function, we are good.

# %%
from torch.utils.data import Dataset
class CustomDataset(Dataset):
    def __init__(self, data, horizon):
        self.data = data
        self.size = len(data)
        self.horizon = horizon
    
    def __len__(self):
        return self.size
    
    def __getitem__(self, idx):
        # get a single item
        item = self.data[idx]
        # slice off the horizon
        x = item[:-self.horizon,:]
        y = item[-self.horizon:,:].squeeze(-1) # squeeze will remove the last dimension if possible.
        return x, y

# %% [markdown]
# Let us test if this works as expected

# %%
datashape = (100, 10, 2)
dummydata = torch.randint(0, 10, datashape)
dummydataset = CustomDataset(dummydata, horizon=2)
len(dummydataset) # uses the __len__ method
# Out:
# 100

# %%
x, y = dummydataset[0] # uses the __getitem__ method
x.shape, y.shape # no squeeze because we have dimension 2 as the last dimension
# Out:
# (torch.Size([8, 2]), torch.Size([2, 2]))

# %% [markdown]
# Ok, now we apply this on the trainset.

# %%
trainset.shape
# Out:
# torch.Size([2475, 26, 1])

# %%
horizon = 3
traindataset = CustomDataset(trainset, horizon=horizon)
testdataset = CustomDataset(testset, horizon=horizon)

# %%
x, y = traindataset[1]
x.shape, y.shape # here we see the squeeze happening
# Out:
# (torch.Size([23, 1]), torch.Size([3]))

# %% [markdown]
# ## 1.5 A Dataloader
# This seems to work as well. Now we can give this to a Dataloader to batch and shuffle it for us.

# %%
trainloader = DataLoader(traindataset, batch_size=32, shuffle=True)
testloader = DataLoader(testdataset, batch_size=32, shuffle=True)

# %% [markdown]
# Can you make sense of all the output?
# What is going on? Is that what you expected?

# %%
x, y = next(iter(trainloader))
x.shape, y.shape # here we see the squeeze in action
# Out:
# (torch.Size([32, 23, 1]), torch.Size([32, 3]))

# %% [markdown]
# What do you think these numbers are?

# %%
len(trainloader.dataset), len(trainloader)
# Out:
# (2475, 78)

# %% [markdown]
# # 2 Exploring baseline models
# ## 2.1 Naive models

# %% [markdown]
# The most basic prediction is a Naive model.
#
# - What is a naive prediction of the temperature for tomorrow? Well, the temperature of today.
# - The stock market for tomorrow? Same as today.
# - Bitcoin for march 16th of 2028? Same as march 15th 2028.
#
# In general, this is a super simple model without any parameters but often much better than you would expect, because the temparature of today will be close to the temperature of tomorrow.
#
# In general, you can say that f is a function that you feed the current moment, which is a real number, and it will map it to one step into the future, which is also a real number.
#
# $$ f: x_t \in \mathcal{R} \to x_{t+1} \in \mathcal{R}$$
#
# but $f$ is just the Identity function $f(x) = x$, so one step into the future is the same as the current timestep.
#
# This gives rise to the MASE, the Mean Absolute Scaled Error: It is the mean absolute error of the forecast values (the actual model)
# $\frac{1}{J}\sum_j|e_j|$, but scaled by the mean absolute error of the in-sample one-step naive forecast $|Y_t-Y_{t-1}|$ (the naive model):
#
# $$ MASE = \frac{\frac{1}{J}\sum_j|e_j|}{
# \frac{1}{T-1} \sum_{t=2}^{T}|Y_t-Y_{t-1}|} $$
#
# This takes a moment in time $t$, and calculates the difference with one step back $t-1$.
#
# In other words, the MASE compares the MAE of your actual model to the MAE of the naive model.
#
# E.g. if the error of your model is 1, and the error of the naive model is 10, your MASE is 0.1, meaning you are much better than the naive prediction.
#
# MASE values above 1 are really bad, because it means the naive function outperformed your actual model, everything below (ideally close to 0) is an improvement.
#
# We will implement this ourselves. First the naive prediction:

# %%
from typing import Tuple
Tensor = torch.Tensor

def naivepredict(x: Tensor, horizon: int) -> Tuple[Tensor, Tensor]:
    assert horizon > 0
    yhat = x[...,-horizon:, :].squeeze(-1)
    return yhat

# %%
yhat = naivepredict(x, horizon) #this should be the same horizon you used to create the dataset
yhat.shape
# Out:
# torch.Size([32, 3])

# %% [markdown]
# With the naive prediction, we can calculate the MAE

# %%
def mae(y: Tensor, yhat: Tensor) -> Tensor:
    return torch.mean(torch.abs(y-yhat))

# %%
mae(y, yhat)
# Out:
# tensor(0.0634)

# %% [markdown]
# This error is not deterministic, because of the shuffling in the dataset.
#
# Now, we want to calculate the naive MAE for every batch, to get the average, expected MAE for the naive prediction

# %%
def naivenorm(dataloader: DataLoader, horizon: int):
    elist = []
    for x, y in dataloader:
        yhat = naivepredict(x, horizon)
        e = mae(y, yhat)
        elist.append(e)
    return torch.mean(torch.tensor(elist))
naivenorm(trainloader, 1)
# Out:
# tensor(0.0561)

# %% [markdown]
# This means, a MAE close to this number is not impressive at all. We need to get below this if we want to go beyond the naive prediction.
# We can wrap everything in a class, so it is neatly organized.
#
# This example also illustrates two other dunder methods, `__repr__` and `__call__`

# %%
Tensor = torch.Tensor
class MASE:
    def __init__(self, dataloader: DataLoader, horizon: int):
        self.scale = self.naivenorm(dataloader, horizon)
    
    def __repr__(self) -> str:
        # __repr__ is what is returned if you print the class to the screen 
        return f"MASE(scale={self.scale:.3f})"

    def naivenorm(self, dataloader: DataLoader, horizon: int):
        elist = []
        for x, y in dataloader:
            yhat = self.naivepredict(x, horizon)
            e = self.mae(y, yhat)
            elist.append(e)
        return torch.mean(torch.tensor(elist))
    
    def naivepredict(self, x: Tensor, horizon: int) -> Tuple[Tensor, Tensor]:
        assert horizon > 0
        yhat = x[...,-horizon:, :].squeeze(-1)
        return yhat

    def mae(self, y: Tensor, yhat: Tensor) -> Tensor:
        return torch.mean(torch.abs(y-yhat))
    
    def __call__(self, y: Tensor, yhat: Tensor) -> Tensor:
        # __call__ lets us call the class as a function
        return self.mae(y, yhat) / self.scale

# %%
mase = MASE(trainloader, horizon)
mase # __repr__ in action
# Out:
# MASE(scale=0.062)

# %%
mase(y, yhat) # __call__ in action
# Out:
# tensor(1.0273)

# %% [markdown]
# ## 2.2 Linear model
# Ok, we have everything in place. Let's start with a slightly more advanced model than a naive one.
#
# We start with a linear baselinemodel, of just a single `Linear` layer with one unit. This is equal to a linear model.
#
# **NOTE** A Neural Network (consisting of Linear layers AND activation layers) is NOT a simple model; if your model is deep & wide enough, this is a universal function approximator! That means a neural network is capable, in theory, of approximating EVERY function. In this case we use a single layer, with a minimum amount of units; that's why this is a simple model!
#
# Check out the sourcecode (tip: VS code let's you do so easily by pressing F12, or by right-clicking the mouse on a function and selecting `Go to Definition`)

# %%
from src.models import rnn_models, metrics
observations = window_size - horizon
model = rnn_models.BaseModel(observations=observations, horizon=horizon)
x, y = next(iter(trainloader))
x.shape, y.shape
# Out:
# (torch.Size([32, 23, 1]), torch.Size([32, 3]))

# %% [markdown]
# Let's have a look at our random model

# %%
yhat = model(x)
yhat.shape
# Out:
# torch.Size([32, 3])

# %%
mase = metrics.MASE(trainloader, horizon)
mase(y, yhat)
# Out:
# tensor(3.5343, grad_fn=<DivBackward0>)

# %% [markdown]
# Oh boy! Untrained, this is actually much much worse than a naive model... Let's start training...
#
# First, we add a regular MAE too.

# %%
mae = metrics.MAE()
mae(yhat, y)
# Out:
# tensor(0.2188, grad_fn=<MeanBackward0>)

# %%
from loguru import logger
logger.remove()
logger.add(sys.stderr, level="SUCCESS")
# Out:
# 1

# %%
from src.models import train_model
from pathlib import Path
gin.parse_config_file("model.gin")

log_dir = Path("../../models/rnn/")

observations = window_size - horizon
model = rnn_models.BaseModel(observations=observations, horizon=horizon)


model, test_loss = train_model.trainloop(
    model=model,
    metrics=[mase, mae],
    train_dataloader=trainloader,
    test_dataloader=testloader,
    log_dir=log_dir,
    train_steps=len(trainloader),
    eval_steps=len(testloader),
    patience=20,
    factor=0.5,
    tunewriter=["tensorboard", "gin"],
)
# Out:
# 100%|██████████| 78/78 [00:00<00:00, 594.10it/s]
# 100%|██████████| 78/78 [00:00<00:00, 812.21it/s]
# 100%|██████████| 78/78 [00:00<00:00, 791.44it/s]
# 100%|██████████| 78/78 [00:00<00:00, 233.88it/s]
# 100%|██████████| 78/78 [00:00<00:00, 706.56it/s]
# 100%|██████████| 78/78 [00:00<00:00, 623.83it/s]
# 100%|██████████| 78/78 [00:00<00:00, 537.07it/s]
# 100%|██████████| 78/78 [00:00<00:00, 541.74it/s]
# 100%|██████████| 78/78 [00:00<00:00, 579.72it/s]
# 100%|██████████| 78/78 [00:00<00:00, 606.91it/s]
# 100%|██████████| 78/78 [00:00<00:00, 574.46it/s]
# 100%|██████████| 78/78 [00:00<00:00, 579.52it/s]
# 100%|██████████| 78/78 [00:00<00:00, 535.33it/s]
# 100%|██████████| 78/78 [00:00<00:00, 476.09it/s]
# 100%|██████████| 78/78 [00:00<00:00, 600.72it/s]
# 100%|██████████| 78/78 [00:00<00:00, 571.03it/s]
# 100%|██████████| 78/78 [00:00<00:00, 588.72it/s]
# 100%|██████████| 78/78 [00:00<00:00, 588.92it/s]
# 100%|██████████| 78/78 [00:00<00:00, 552.25it/s]
# 100%|██████████| 78/78 [00:00<00:00, 573.81it/s]
# 100%|██████████| 78/78 [00:00<00:00, 501.42it/s]
# 100%|██████████| 78/78 [00:00<00:00, 631.37it/s]
# 100%|██████████| 78/78 [00:00<00:00, 648.84it/s]
# 100%|██████████| 78/78 [00:00<00:00, 437.66it/s]
# 100%|██████████| 78/78 [00:00<00:00, 623.02it/s]
# 100%|██████████| 78/78 [00:00<00:00, 639.85it/s]
# 100%|██████████| 78/78 [00:00<00:00, 704.23it/s]
# 100%|██████████| 78/78 [00:00<00:00, 658.05it/s]
# 100%|██████████| 78/78 [00:00<00:00, 807.74it/s]
# 100%|██████████| 78/78 [00:00<00:00, 700.63it/s]
# 100%|██████████| 78/78 [00:00<00:00, 728.52it/s]
# 100%|██████████| 78/78 [00:00<00:00, 808.34it/s]
# 100%|██████████| 78/78 [00:00<00:00, 799.98it/s]
# 100%|██████████| 78/78 [00:00<00:00, 829.92it/s]
# 100%|██████████| 78/78 [00:00<00:00, 817.23it/s]
# 100%|██████████| 78/78 [00:00<00:00, 826.95it/s]
# 100%|██████████| 78/78 [00:00<00:00, 848.66it/s]
# 100%|██████████| 78/78 [00:00<00:00, 796.42it/s]
# 100%|██████████| 78/78 [00:00<00:00, 623.84it/s]
# 100%|██████████| 78/78 [00:00<00:00, 788.46it/s]
# 100%|██████████| 78/78 [00:00<00:00, 825.92it/s]
# 100%|██████████| 78/78 [00:00<00:00, 817.23it/s]
# 100%|██████████| 78/78 [00:00<00:00, 418.40it/s]
# 100%|██████████| 78/78 [00:00<00:00, 679.83it/s]
# 100%|██████████| 78/78 [00:00<00:00, 695.61it/s]
# 100%|██████████| 78/78 [00:00<00:00, 803.97it/s]
# 100%|██████████| 78/78 [00:00<00:00, 754.83it/s]
# 100%|██████████| 78/78 [00:00<00:00, 804.44it/s]
# 100%|██████████| 78/78 [00:00<00:00, 809.60it/s]
# 100%|██████████| 78/78 [00:00<00:00, 787.72it/s]
# 100%|██████████| 78/78 [00:00<00:00, 814.19it/s]
# 100%|██████████| 78/78 [00:00<00:00, 825.18it/s]
# 100%|██████████| 78/78 [00:00<00:00, 834.71it/s]
# 100%|██████████| 78/78 [00:00<00:00, 848.11it/s]
# 100%|██████████| 78/78 [00:00<00:00, 822.24it/s]
# 100%|██████████| 78/78 [00:00<00:00, 616.15it/s]
# 100%|██████████| 78/78 [00:00<00:00, 757.74it/s]
# 100%|██████████| 78/78 [00:00<00:00, 792.58it/s]
# 100%|██████████| 78/78 [00:00<00:00, 804.81it/s]
# 100%|██████████| 78/78 [00:00<00:00, 798.42it/s]
# 100%|██████████| 78/78 [00:00<00:00, 762.91it/s]
# 100%|██████████| 78/78 [00:00<00:00, 788.95it/s]
# 100%|██████████| 78/78 [00:00<00:00, 791.02it/s]
# 100%|██████████| 78/78 [00:00<00:00, 707.10it/s]
# 100%|██████████| 78/78 [00:00<00:00, 824.08it/s]
# 100%|██████████| 78/78 [00:00<00:00, 808.09it/s]
# 100%|██████████| 78/78 [00:00<00:00, 412.31it/s]
# 100%|██████████| 78/78 [00:00<00:00, 537.00it/s]
# 100%|██████████| 78/78 [00:00<00:00, 599.59it/s]
# 100%|██████████| 78/78 [00:00<00:00, 389.03it/s]
# 100%|██████████| 78/78 [00:00<00:00, 555.32it/s]
# 100%|██████████| 78/78 [00:00<00:00, 636.48it/s]
# 100%|██████████| 78/78 [00:00<00:00, 547.35it/s]
# 100%|██████████| 78/78 [00:00<00:00, 636.55it/s]
# 100%|██████████| 78/78 [00:00<00:00, 584.50it/s]
# 100%|██████████| 78/78 [00:00<00:00, 623.96it/s]
# 100%|██████████| 78/78 [00:00<00:00, 638.85it/s]
# 100%|██████████| 78/78 [00:00<00:00, 617.82it/s]
# 100%|██████████| 78/78 [00:00<00:00, 594.70it/s]
# 100%|██████████| 78/78 [00:00<00:00, 424.18it/s]
# 100%|██████████| 78/78 [00:00<00:00, 614.28it/s]
# 100%|██████████| 78/78 [00:00<00:00, 567.47it/s]
# 100%|██████████| 78/78 [00:00<00:00, 644.22it/s]
# 100%|██████████| 78/78 [00:00<00:00, 629.09it/s]
# 100%|██████████| 78/78 [00:00<00:00, 625.75it/s]
# 100%|██████████| 78/78 [00:00<00:00, 607.20it/s]
# 100%|██████████| 78/78 [00:00<00:00, 579.24it/s]
# 100%|██████████| 78/78 [00:00<00:00, 665.35it/s]
# 100%|██████████| 78/78 [00:00<00:00, 704.27it/s]
# 100%|██████████| 78/78 [00:00<00:00, 708.67it/s]
# 100%|██████████| 78/78 [00:00<00:00, 780.60it/s]
# 100%|██████████| 78/78 [00:00<00:00, 707.80it/s]
# 100%|██████████| 78/78 [00:00<00:00, 780.13it/s]
# 100%|██████████| 78/78 [00:00<00:00, 309.39it/s]
# 100%|██████████| 78/78 [00:00<00:00, 679.46it/s]
# 100%|██████████| 78/78 [00:00<00:00, 680.71it/s]
# 100%|██████████| 78/78 [00:00<00:00, 708.30it/s]
# 100%|██████████| 78/78 [00:00<00:00, 717.94it/s]
# 100%|██████████| 78/78 [00:00<00:00, 684.02it/s]
# 100%|██████████| 78/78 [00:00<00:00, 446.58it/s]
# 100%|██████████| 100/100 [00:16<00:00,  6.22it/s]

# %% [markdown]
# If you have a look at Tensorboard, you can see the model is learning!

# %%
x, y = next(iter(testloader))
yhat = model(x)
mae(y, yhat), mase(y, yhat)
# Out:
# (tensor(0.0434, grad_fn=<MeanBackward0>),
#  tensor(0.7014, grad_fn=<DivBackward0>))

# %% [markdown]
# And, yes, the MASE dropped below 1! This is a good start.
#
# Let's visualize this.

# %%
k = 4
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
axs = ax.ravel()

timesteps = x.shape[1]
idx0 = [*range(timesteps)]
idx1 = [(i + timesteps) for i in range(horizon)]
for i in range(k):
    axs[i].plot(idx0, x[i])
    axs[i].plot(idx1, yhat[i].detach(), color="red", label="predict")
    axs[i].plot(idx1, y[i], color="green", label="actual")
handles, labels = axs[i].get_legend_handles_labels()
fig.legend(handles, labels)

# %% [markdown]
# Well, it is not perfect, obviously. But it does seem to capture the trend.

# %% [markdown]
# ## 2.3 Simple RNN

# %% [markdown]
# Let's invoke the basic RNN without gates.
#
# Input size is 1, because we have 1 feature. We follow [the batch_first convention](https://pytorch.org/docs/stable/generated/torch.nn.RNN.html). Hidden size is the inner dimension of the RNN, and thus the dimensionality of the output.
#
# What would happen if we feed this data with dimensions `(batch, sequence_length)`?

# %%
x = torch.randn((32, 25))
rnn = torch.nn.RNN(input_size=1, hidden_size=1, batch_first=True)
try:
    yhat = rnn(x)
except RuntimeError as e:
    print(e)
# Out:
# input.size(-1) must be equal to input_size. Expected 1, got 25

# %% [markdown]
# Note how it expects 3 dimensions : `(batch, sequence_length, features)`, even though we have just one feature.

# %%
x, y = next(iter(trainloader))
x.shape, y.shape
# Out:
# (torch.Size([32, 23, 1]), torch.Size([32, 3]))

# %%
out, hidden = rnn(x)
out.shape, hidden.shape
# Out:
# (torch.Size([32, 23, 1]), torch.Size([1, 32, 1]))

# %% [markdown]
# This works as expected. Let's increase the hidden dimension (why would you do that?)

# %%
rnn = torch.nn.RNN(input_size=1, hidden_size=10, batch_first=True)
out, hidden = rnn(x)
out.shape, hidden.shape
# Out:
# (torch.Size([32, 23, 10]), torch.Size([1, 32, 10]))

# %% [markdown]
# And let's add multiple stacked layers of RNN (can you visualize how this would work?)

# %%
rnn = torch.nn.RNN(
    input_size=1,
    hidden_size=10,
    num_layers=3,
    batch_first=True)
out, hidden = rnn(x)
out.shape, hidden.shape
# Out:
# (torch.Size([32, 23, 10]), torch.Size([3, 32, 10]))

# %% [markdown]
# To get the output of the last timestep, we need to throw away the rest.

# %%
out = out[:,-1,:]
out.shape
# Out:
# torch.Size([32, 10])

# %% [markdown]
# So, let's wrap this up in a model. Study the implementation in `rnn_models.BaseRNN`.
#
# Do you understand what the linear layer does? What would happen if you remove it?

# %%
from src.models import metrics, rnn_models

mase = metrics.MASE(trainloader, horizon)
mae = metrics.MAE()

# %%
gin.parse_config_file("model.gin")

observations = window_size - horizon
model = rnn_models.BaseRNN(horizon=horizon)

model, testloss = train_model.trainloop(
    model=model,
    metrics=[mase, mae],
    learning_rate=1e-3,
    train_dataloader=trainloader,
    test_dataloader=testloader,
    log_dir=log_dir,
    train_steps=len(trainloader),
    eval_steps=len(testloader),
    tunewriter=["tensorboard", "gin"],
    patience=10,
    factor=0.5
)
# Out:
# 100%|██████████| 78/78 [00:00<00:00, 110.54it/s]
#   0%|          | 0/100 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[44], line 6
#       3 observations = window_size - horizon
#       4 model = rnn_models.BaseRNN(horizon=horizon)
# ----> 6 model, testloss = train_model.trainloop(
#       7     model=model,
#       8     metrics=[mase, mae],
#       9     learning_rate=1e-3,
#      10     train_dataloader=trainloader,
#      11     test_dataloader=testloader,
#      12     log_dir=log_dir,
#      13     train_steps=len(trainloader),
#      14     eval_steps=len(testloader),
#      15     tunewriter=["tensorboard", "gin", "mlflow"],
#      16     patience=10,
#      17     factor=0.5
#      18 )
#
# File ~/.cache/pypoetry/virtualenvs/deep-learning-jHmOY0S3-py3.10/lib/python3.10/site-packages/gin/config.py:1605, in _make_gin_wrapper.<locals>.gin_wrapper(*args, **kwargs)
#    1603 scope_info = " in scope '{}'".format(scope_str) if scope_str else ''
#    1604 err_str = err_str.format(name, fn_or_cls, scope_info)
# -> 1605 utils.augment_exception_message_and_reraise(e, err_str)
#
# File ~/.cache/pypoetry/virtualenvs/deep-learning-jHmOY0S3-py3.10/lib/python3.10/site-packages/gin/utils.py:41, in augment_exception_message_and_reraise(exception, message)
#      39 proxy = ExceptionProxy()
#      40 ExceptionProxy.__qualname__ = type(exception).__qualname__
# ---> 41 raise proxy.with_traceback(exception.__traceback__) from None
#
# File ~/.cache/pypoetry/virtualenvs/deep-learning-jHmOY0S3-py3.10/lib/python3.10/site-packages/gin/config.py:1582, in _make_gin_wrapper.<locals>.gin_wrapper(*args, **kwargs)
#    1579 new_kwargs.update(kwargs)
#    1581 try:
# -> 1582   return fn(*new_args, **new_kwargs)
#    1583 except Exception as e:  # pylint: disable=broad-except
#    1584   err_str = ''
#
# File /workspaces/ML22/notebooks/3_recurrent_networks/../../src/models/train_model.py:167, in trainloop(epochs, model, optimizer, learning_rate, loss_fn, metrics, train_dataloader, test_dataloader, log_dir, train_steps, eval_steps, patience, factor, tunewriter, weight_decay)
#     165 mlflow.log_metric("test loss", test_loss, step=epoch)
#     166 for m in metric_dict:
# --> 167     mlflow.log_metric(f"metric/{m}", metric_dict[m], step=epoch)
#     168 lr = [group["lr"] for group in optimizer_.param_groups][0]
#     169 mlflow.log_metric("learning_rate", lr, step=epoch)
#
# File ~/.cache/pypoetry/virtualenvs/deep-learning-jHmOY0S3-py3.10/lib/python3.10/site-packages/mlflow/tracking/fluent.py:646, in log_metric(key, value, step)
#     622 """
#     623 Log a metric under the current run. If no run is active, this method will create
#     624 a new active run.
#    (...)
#     643         mlflow.log_metric("mse", 2500.00)
#     644 """
#     645 run_id = _get_or_start_run().info.run_id
# --> 646 MlflowClient().log_metric(run_id, key, value, get_current_time_millis(), step or 0)
#
# File ~/.cache/pypoetry/virtualenvs/deep-learning-jHmOY0S3-py3.10/lib/python3.10/site-packages/mlflow/tracking/client.py:703, in MlflowClient.log_metric(self, run_id, key, value, timestamp, step)
#     638 def log_metric(
#     639     self,
#     640     run_id: str,
#    (...)
#     644     step: Optional[int] = None,
#     645 ) -> None:
#     646     """
#     647     Log a metric against the run ID.
#     648
#    (...)
#     701         status: FINISHED
#     702     """
# --> 703     self._tracking_client.log_metric(run_id, key, value, timestamp, step)
#
# File ~/.cache/pypoetry/virtualenvs/deep-learning-jHmOY0S3-py3.10/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:286, in TrackingServiceClient.log_metric(self, run_id, key, value, timestamp, step)
#     284 metric_value = convert_metric_value_to_float_if_possible(value)
#     285 metric = Metric(key, metric_value, timestamp, step)
# --> 286 self.store.log_metric(run_id, metric)
#
# File ~/.cache/pypoetry/virtualenvs/deep-learning-jHmOY0S3-py3.10/lib/python3.10/site-packages/mlflow/store/tracking/file_store.py:911, in FileStore.log_metric(self, run_id, metric)
#     909 def log_metric(self, run_id, metric):
#     910     _validate_run_id(run_id)
# --> 911     _validate_metric(metric.key, metric.value, metric.timestamp, metric.step)
#     912     run_info = self._get_run_info(run_id)
#     913     check_run_is_active(run_info)
#
# File ~/.cache/pypoetry/virtualenvs/deep-learning-jHmOY0S3-py3.10/lib/python3.10/site-packages/mlflow/utils/validation.py:132, in _validate_metric(key, value, timestamp, step)
#     127 def _validate_metric(key, value, timestamp, step):
#     128     """
#     129     Check that a metric with the specified key, value, timestamp, and step is valid and raise an
#     130     exception if it isn't.
#     131     """
# --> 132     _validate_metric_name(key)
#     133     # value must be a Number
#     134     # since bool is an instance of Number check for bool additionally
#     135     if not _is_numeric(value):
#
# File ~/.cache/pypoetry/virtualenvs/deep-learning-jHmOY0S3-py3.10/lib/python3.10/site-packages/mlflow/utils/validation.py:107, in _validate_metric_name(name)
#     102     raise MlflowException(
#     103         f"Metric name cannot be None. {_MISSING_KEY_NAME_MESSAGE}",
#     104         error_code=INVALID_PARAMETER_VALUE,
#     105     )
#     106 if not _VALID_PARAM_AND_METRIC_NAMES.match(name):
# --> 107     raise MlflowException(
#     108         f"Invalid metric name: '{name}'. {_BAD_CHARACTERS_MESSAGE}",
#     109         INVALID_PARAMETER_VALUE,
#     110     )
#     111 if path_not_unique(name):
#     112     raise MlflowException(
#     113         "Invalid metric name: '{}'. {}".format(name, bad_path_message(name)),
#     114         INVALID_PARAMETER_VALUE,
#     115     )
#
# MlflowException: Invalid metric name: 'metric/MASE(scale=0.062)'. Names may only contain alphanumerics, underscores (_), dashes (-), periods (.), spaces ( ), and slashes (/).
#   In call to configurable 'trainloop' (<function trainloop at 0x7f17818ce950>)

# %% [markdown]
# Does this improve over the linear model?
# By how much? Is there a difference between loss and MASE?
#
# What does it mean?
#
# Can you improve the model by tweaking it?

# %%
testloss
# Out:
# 0.003533000824972987
